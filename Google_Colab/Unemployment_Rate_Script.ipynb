# %%
# Reading .nc files from Colab/Thesis

# Importing libraries
import os
# Mount Google Drive (if you want to access files from Google Drive)
from google.colab import drive
drive.mount('/content/drive')
# Set the desired working directory
os.chdir('/content/drive/My Drive/Thesis')
# Verify the current working directory
print("Current working directory:", os.getcwd())
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Current working directory: /content/drive/My Drive/Thesis

# %%
# !ls
# Out:
# 'CSVs: Scenario: SSP119 - RCP 1.9'
# 'CSVs: Scenario: SSP126 - RCP 2.6'
# 'CSVs: Scenario: SSP245 - RCP 4.5'
# 'CSVs: Scenario: SSP585 - RCP 8.5'
# 'Final_Script_SSP1 - RCP 1.9.ipynb'
#  first_tas_Amon_GFDL-ESM4_ssp119_r1i1p1f1_gr1_201501-210012.nc
#  fourth_tas_Amon_GFDL-ESM4_ssp585_r1i1p1f1_gr1_201501-210012.nc
#  GDP
#  GDP_Per_Capita_script.ipynb
#  GeoJson_Shapefiles
#  mexico.json
#  script_clean_nc_files.ipynb
#  script_reading_geoj.ipynb
#  second_tas_Amon_GFDL-ESM4_ssp370_r1i1p1f1_gr1_201501-210012.nc
# 'Temperature fluctuations in Mexico: Scenario: SSP1 - RCP 2.6.csv'
#  third_tas_Amon_GFDL-ESM4_ssp119_r1i1p1f1_gr1_201501-210012.nc
#  Unemployment_rate
#  Unemployment_Rate_Script.ipynb

# %%
import pandas as pd


file_path = 'Unemployment_rate/Unemployment_rate.csv'

# Read the CSV file into a DataFrame
df = pd.read_csv(file_path)
df.head()
# Out:
#   Country Name Country Code  \
# 0       Mexico          MEX
# 1  El Salvador          SLV
# 2    Guatemala          GTM
# 3     Honduras          HND
#
#                                       Indicator Name   1991   1992   1993  \
# 0  Unemployment, total (% of total labor force) (...  3.150  3.240  3.370
# 1  Unemployment, total (% of total labor force) (...  7.530  7.880  9.940
# 2  Unemployment, total (% of total labor force) (...  2.696  2.652  2.612
# 3  Unemployment, total (% of total labor force) (...  4.580  3.060  3.098
#
#     1994  1995   1996   1997  ...  2014  2015  2016  2017  2018  2019   2020  \
# 0  4.440  7.10  5.470  4.240  ...  4.81  4.31  3.85  3.42  3.27  3.48   4.44
# 1  7.680  7.65  7.680  7.980  ...  4.15  4.00  4.42  4.39  4.01  4.17   5.01
# 2  2.595  2.59  2.638  2.623  ...  2.72  2.51  2.58  2.46  2.28  2.19   2.88
# 3  3.137  3.24  4.370  3.320  ...  7.08  6.15  6.73  5.53  5.62  5.55  10.68
#
#    2021   2022   2023
# 0  4.09  3.260  2.821
# 1  4.33  3.000  2.766
# 2  2.17  3.050  3.155
# 3  8.23  6.998  6.784
#
# [4 rows x 36 columns]
